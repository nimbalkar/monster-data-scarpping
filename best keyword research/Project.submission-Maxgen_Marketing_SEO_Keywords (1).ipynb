# %% [markdown]
# ## Finding Keywords from Research Papers for the  Marketing of AI Conference with the help of NLP

# %%
#importing all required packages and libraries
import operator
import itertools
import numpy as np
import pandas as pd
import nltk 
import nltk.corpus
from nltk.tokenize import word_tokenize,sent_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.cluster import KMeans

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
#importing data set
df = pd.read_csv('college_reserach_papers.csv')
#displaying first 5 rows of dataframe
df.head()
# Out:
#                                                title  \
# 0              Kernelized Bayesian Transfer Learning
# 1  "Source Free" Transfer Learning for Text Class...
# 2  A Generalization of Probabilistic Serial to Ra...
# 3         Lifetime Lexical Variation in Social Media
# 4  Hybrid Singular Value Thresholding for Tensor ...
#
#                                              authors  \
# 0                  Mehmet Gönen and Adam A. Margolin
# 1  Zhongqi Lu, Yin Zhu, Sinno Pan, Evan Xiang, Yu...
# 2                      Haris Aziz and Paul Stursberg
# 3  Liao Lizi, Jing Jiang, Ying Ding, Heyan Huang ...
# 4   Xiaoqin Zhang, Zhengyuan Zhou, Di Wang and Yi Ma
#
#                                               groups  \
# 0           Novel Machine Learning Algorithms (NMLA)
# 1  AI and the Web (AIW)\nNovel Machine Learning A...
# 2          Game Theory and Economic Paradigms (GTEP)
# 3                        NLP and Text Mining (NLPTM)
# 4  Knowledge Representation and Reasoning (KRR)\n...
#
#                                             keywords  \
# 0  cross-domain learning\ndomain adaptation\nkern...
# 1  Transfer Learning\nAuxiliary Data Retrieval\nT...
# 2  social choice theory\nvoting\nfair division\ns...
# 3  Generative model\nSocial Networks\nAge Prediction
# 4  tensor completion\nlow-rank recovery\nhybrid s...
#
#                                               topics  \
# 0  APP: Biomedical / Bioinformatics\nNMLA: Bayesi...
# 1  AIW: Knowledge acquisition from the web\nAIW: ...
# 2    GTEP: Game Theory\nGTEP: Social Choice / Voting
# 3  AIW: Web personalization and user modeling\nNL...
# 4  KRR: Knowledge Representation (General/Other)\...
#
#                                             abstract
# 0  Transfer learning considers related but distin...
# 1  Transfer learning uses relevant auxiliary data...
# 2  The probabilistic serial (PS) rule is one of t...
# 3  As the rapid growth of online social media att...
# 4  In this paper, we study the low-rank tensor co...

# %%
#As abstract and other columns  are too descriptive and not making much sence for analysis so dropping that column and considering rest
ndf = df[['title','groups','keywords','topics']]

# %%
#saving new dataframe as csv file
ndf.to_csv('new.csv')

# %%
type(ndf.groups)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Data Cleaning

# %%
#removing "\n" and "/" from all data
ndf = ndf.replace(r'\n',' ', regex=True) 
ndf = ndf.replace(r' /',' ', regex=True) 
ndf = ndf.replace(r', ,,',' ', regex=True)

# %%
#cleaned dataframe
ndf
# Out:
#                                                  title  \
# 0                Kernelized Bayesian Transfer Learning
# 1    "Source Free" Transfer Learning for Text Class...
# 2    A Generalization of Probabilistic Serial to Ra...
# 3           Lifetime Lexical Variation in Social Media
# 4    Hybrid Singular Value Thresholding for Tensor ...
# 5                          Locality Preserving Hashing
# 6    Discovering Better AAAI Keywords via Clusterin...
# 7       Online Classification Using a Voted RDA Method
# 8    Fraudulent Support Telephone Number Identifica...
# 9    Supervised Hashing for Image Retrieval via Ima...
# 10           Tailoring Local Search for Partial MaxSAT
# 11   R2: An Efficient MCMC Sampler for Probabilisti...
# 12   Reconsidering Mutual Information Based Feature...
# 13   Influence Maximization with Novelty Decay in S...
# 14   Solving Uncertain MDPs by Reusing State Inform...
# 15   Identifying Differences in Physician Communica...
# 16   Multi-Organ Exchange: The Whole is Greater tha...
# 17   A Latent Variable Model for Discovering Bird S...
# 18   Cross-View Feature Learning for Scalable Socia...
# 19   Semantic Graph Construction for Weakly-Supervi...
# 20   The Importance of Cognition and Affect for Art...
# 21     The Complexity of Reasoning with FODD and GFODD
# 22   Scalable Complex Contract Negotiation With Str...
# 23   Manifold Learning for Jointly Modeling Topic a...
# 24   Constructing Symbolic Representations for High...
# 25   Towards Understanding Unscripted Gesture and L...
# 26   Intelligent System for Urban Emergency Managem...
# 27   Cached Iterative Weakening for Optimal Multi-W...
# 28                     Online Social Spammer Detection
# 29   Modeling and Predicting Popularity Dynamics vi...
# ..                                                 ...
# 368  CoreCluster: A Degeneracy Based Graph Clusteri...
# 369  A Generalized Genetic Algorithm-Based Solver f...
# 370  Solving Zero-Sum Security Games in Discretized...
# 371  Q-intersection Algorithms for Constraint-Based...
# 372  Fused Feature Representation Discovery for Hig...
# 373  Joule Counting Correction for Electric Vehicle...
# 374  Managing Change in Graph-structured Data Using...
# 375     BCI Based Control Without Explicit Calibration
# 376  Towards Scalable Exploration of Diagnoses in a...
# 377  Flexible and Scalable Partially Observable Pla...
# 378     Online Portfolio Selection with Group Sparsity
# 379  Prediction of Helpful Reviews using Emotions E...
# 380  An Adversarial Interpretation of Information-T...
# 381  Learning to Recognize Novel Objects in One Sho...
# 382  Coactive Learning for Locally Optimal Problem ...
# 383                   Large Scale Analogical Reasoning
# 384                  Learning Models of Unknown Events
# 385  Learning Concept Embeddings for Query Expansio...
# 386  Non-Restarting SAT Solvers With Simple Preproc...
# 387  Worst-Case Solution Quality Analysis When Not ...
# 388               Natural Temporal Difference Learning
# 389  Relaxation Search: a Simple Way of Managing Op...
# 390  Using Response Functions to Measure Strategy S...
# 391  Optimal and Efficient Stochastic Motion Planni...
# 392           Learning Scripts as Hidden Markov Models
# 393  Mapping Users Across Networks by Manifold Alig...
# 394  Compact Aspect Embedding For Diversified Query...
# 395       Contraction and Revision over DL-Lite TBoxes
# 396                 Zero Pronoun Resolution as Ranking
# 397                  Supervised Transfer Sparse Coding
#
#                                                 groups  \
# 0             Novel Machine Learning Algorithms (NMLA)
# 1    AI and the Web (AIW) Novel Machine Learning Al...
# 2            Game Theory and Economic Paradigms (GTEP)
# 3                          NLP and Text Mining (NLPTM)
# 4    Knowledge Representation and Reasoning (KRR) M...
# 5                                         Vision (VIS)
# 6                  Machine Learning Applications (MLA)
# 7    Machine Learning Applications (MLA) NLP and Ma...
# 8                                 AI and the Web (AIW)
# 9    Novel Machine Learning Algorithms (NMLA) Visio...
# 10   Heuristic Search and Optimization (HSO) Search...
# 11   Novel Machine Learning Algorithms (NMLA) Reaso...
# 12            Novel Machine Learning Algorithms (NMLA)
# 13                                AI and the Web (AIW)
# 14                        Planning and Scheduling (PS)
# 15   Applications (APP) Machine Learning Applicatio...
# 16   Applications (APP) Game Theory and Economic Pa...
# 17          Computational Sustainability and AI (CSAI)
# 18                                AI and the Web (AIW)
# 19                                        Vision (VIS)
# 20   Cognitive Modeling (CM) Cognitive Systems (CS)...
# 21        Knowledge Representation and Reasoning (KRR)
# 22                            Multiagent Systems (MAS)
# 23            Novel Machine Learning Algorithms (NMLA)
# 24            Novel Machine Learning Algorithms (NMLA)
# 25   Humans and AI (HAI) NLP and Machine Learning (...
# 26          Computational Sustainability and AI (CSAI)
# 27   Heuristic Search and Optimization (HSO) Planni...
# 28   AI and the Web (AIW) Machine Learning Applicat...
# 29                                  Applications (APP)
# ..                                                 ...
# 368            AI and the Web (AIW) Applications (APP)
# 369  Novel Machine Learning Algorithms (NMLA) Visio...
# 370  Game Theory and Economic Paradigms (GTEP) Mult...
# 371           Search and Constraint Satisfaction (SCS)
# 372  NLP and Machine Learning (NLPML) Novel Machine...
# 373  Applications (APP) Machine Learning Applicatio...
# 374       Knowledge Representation and Reasoning (KRR)
# 375        Cognitive Modeling (CM) Humans and AI (HAI)
# 376                               AI and the Web (AIW)
# 377  Knowledge Representation and Reasoning (KRR) P...
# 378  Applications (APP) Game Theory and Economic Pa...
# 379  Machine Learning Applications (MLA) NLP and Ma...
# 380  Game Theory and Economic Paradigms (GTEP) Plan...
# 381  Cognitive Systems (CS) Robotics (ROB) Vision (...
# 382  Humans and AI (HAI) Knowledge Representation a...
# 383  Cognitive Systems (CS) Knowledge Representatio...
# 384                             Cognitive Systems (CS)
# 385  NLP and Knowledge Representation (NLPKR) NLP a...
# 386           Search and Constraint Satisfaction (SCS)
# 387            Heuristic Search and Optimization (HSO)
# 388           Novel Machine Learning Algorithms (NMLA)
# 389           Search and Constraint Satisfaction (SCS)
# 390          Game Theory and Economic Paradigms (GTEP)
# 391    Reasoning under Uncertainty (RU) Robotics (ROB)
# 392  NLP and Machine Learning (NLPML) Novel Machine...
# 393                               AI and the Web (AIW)
# 394                               AI and the Web (AIW)
# 395       Knowledge Representation and Reasoning (KRR)
# 396                        NLP and Text Mining (NLPTM)
# 397           Novel Machine Learning Algorithms (NMLA)
#
#                                               keywords  \
# 0    cross-domain learning domain adaptation kernel...
# 1    Transfer Learning Auxiliary Data Retrieval Tex...
# 2    social choice theory voting fair division soci...
# 3      Generative model Social Networks Age Prediction
# 4    tensor completion low-rank recovery hybrid sin...
# 5    Similarity Search Approximate Nearest Neighbor...
# 6    constraint-based clustering machine learning c...
# 7    Online Classification Voted Dual Averaging Met...
# 8    Fraudulent Support Telephone Number Co-occurre...
# 9    supervised hashing approximate near neighbor s...
# 10              Partial MaxSAT Local Search Heuristics
# 11   Probabilistic programming Program analysis Sam...
# 12   feature selection mutual information global op...
# 13   social networks influence maximization novelty...
# 14   Markov Decision Processes (MDPs) Replanning In...
# 15   Conversation modeling Patient-doctor communica...
# 16   Kidney exchange Sparse random graphs Computati...
# 17   Probabilistic Graphical Model Crowdsourcing Ci...
# 18   Cross-View Learning Feature Learning Random Pr...
# 19   Weakly-Supervised Learning Image Parsing Graph...
# 20   Mind perception cognition affect Decision maki...
# 21   Decision Diagrams Computational Complexity Fir...
# 22   Large-scale Negotiation Interdependent Issues ...
# 23   document visualization dimensionality reductio...
# 24      Reinforcement learning Planning Representation
# 25   Human-Robot Interaction Robotics Natural Langu...
# 26   Emergency Management Disaster Informatics Huma...
# 27   Heuristic Search Optimization Search Schedulin...
# 28         Social Media Social Spammer Online Learning
# 29   Social Dynamics Poisson Process Popularity Pre...
# ..                                                 ...
# 368  Community detection Graph clustering Graph deg...
# 369  genetic algorithms jigsaw puzzle computer visi...
# 370  Security Games Zero-Sum Games Minimax Equilibr...
# 371  intersection graph computational complexity pa...
# 372  feature representation discovery feature selec...
# 373  Electric Vehicles Battery Estimation State of ...
# 374  Graph structured data Description Logics Stati...
# 375  Brain-Computer Interfaces Calibration Human-Ro...
# 376  Semantic Web Ontology Stream Semantic Reasonin...
# 377  Planning with sensing and partial information ...
# 378  online learning portfolio selection group lass...
# 379  helpfulness prediction product review analysis...
# 380  bounded rationality free energy game theory le...
# 381  one-shot learning object recognition natural l...
# 382  Coactive Learning Local Optimization Preferenc...
# 383  analogical reasoning case-based reasoning ques...
# 384  learning environment models explanation genera...
# 385           Embedding Density Matrix Query Expansion
# 386  clause learning satisfiability proof complexit...
# 387  best-first search re-expansions heuristics inc...
# 388  natural gradient temporal difference learning ...
# 389  Constraint Optimization Satisfiability Maximum...
# 390  strategy evaluation extensive-form games adapt...
# 391  Planning under uncertainty Motion planning wit...
# 392   HMM Scripts NLP Structural EM Structure Learning
# 393  Social Networks Manifold Alignment Hypergraph ...
# 394  query expansion search result diversification ...
# 395  Belief Change Description Logic Non-monotonic ...
# 396  Zero Pronouns Text Mining Natural Language Pro...
# 397  Sparse coding Transfer learning Supervised lea...
#
#                                                 topics
# 0    APP: Biomedical  Bioinformatics NMLA: Bayesian...
# 1    AIW: Knowledge acquisition from the web AIW: M...
# 2        GTEP: Game Theory GTEP: Social Choice  Voting
# 3    AIW: Web personalization and user modeling NLP...
# 4    KRR: Knowledge Representation (General/Other) ...
# 5                       VIS: Image and Video Retrieval
# 6           MLA: Applications of Unsupervised Learning
# 7    MLA: Machine Learning Applications (General/ot...
# 8    AIW: Enhancing web search and information retr...
# 9    NMLA: Neural Networks/Deep Learning VIS: Image...
# 10   HSO: Heuristic Search HSO: Optimization SCS: C...
# 11   MLA: Machine Learning Applications (General/ot...
# 12   NMLA: Data Mining and Knowledge Discovery NMLA...
# 13   AIW: Social networking and community identific...
# 14   PS: Probabilistic Planning PS: Replanning and ...
# 15   APP: Biomedical  Bioinformatics MLA: Bio/Medic...
# 16   APP: Biomedical  Bioinformatics GTEP: Auctions...
# 17   CSAI: Modeling and prediction of dynamic and s...
# 18   AIW: AI for multimedia and multimodal web appl...
# 19         VIS: Categorization VIS: Object Recognition
# 20   CM: Simulating Humans CS: Problem solving and ...
# 21   KRR: Automated Reasoning and Theorem Proving K...
# 22   MAS: Distributed Problem Solving MAS: Mechanis...
# 23   NMLA: Data Mining and Knowledge Discovery NMLA...
# 24   NMLA: Reinforcement Learning PS: Learning Mode...
# 25   APP: Other Applications HAI: Language Acquisit...
# 26   CSAI: Modeling and prediction of dynamic and s...
# 27   HSO: Heuristic Search HSO: Optimization HSO: S...
# 28   AIW: Machine learning and the web AIW: Recogni...
# 29   APP: Computational Social Science APP: Social ...
# ..                                                 ...
# 368  AIW: Social networking and community identific...
# 369     NMLA: Evolutionary Computation VIS: Perception
# 370  GTEP: Game Theory GTEP: Equilibrium MAS: Multi...
# 371                       SCS: Constraint Satisfaction
# 372  NLPML: Natural Language Processing (General/Ot...
# 373  APP: Other Applications MLA: Applications of U...
# 374  KRR: Computational Complexity of Reasoning KRR...
# 375  CM: Adaptive Behavior HAI: Brain-Sensing and A...
# 376  AIW: Languages, tools, and methodologies for r...
# 377  KRR: Reasoning with Beliefs PS: Deterministic ...
# 378  APP: Other Applications GTEP: Adversarial Lear...
# 379  MLA: Applications of Supervised Learning NLPML...
# 380  PS: Probabilistic Planning PS: Planning (Gener...
# 381  CS: Natural language understanding and dialogu...
# 382  HCC: Active learning from imperfect human labe...
# 383  CS: Conceptual inference and reasoning CS: Str...
# 384  CM: Symbolic AI CS: Problem solving and decisi...
# 385  NLPKR: Natural Language Processing (General/Ot...
# 386  SCS: Constraint Satisfaction SCS: Constraint L...
# 387  HSO: Heuristic Search HSO: Evaluation and Anal...
# 388                                                NaN
# 389  SCS: Constraint Optimization SCS: SAT and CSP:...
# 390  GTEP: Game Theory GTEP: Equilibrium GTEP: Impe...
# 391  PS: Mixed Discrete/Continuous Planning RU: Unc...
# 392  NLPML: Natural Language Processing (General/Ot...
# 393  AIW: Machine learning and the web AIW: Ontolog...
# 394  AIW: Enhancing web search and information retr...
# 395  KRR: Belief Change KRR: Description Logics KRR...
# 396                     NLPTM: Evaluation and Analysis
# 397  NMLA: Classification NMLA: Transfer, Adaptatio...
#
# [398 rows x 4 columns]

# %% [markdown]
# ### word_tokenize

# %%
#tokenizing all columns (word_tokenize)

ndf['title'] = ndf['title'].map(lambda x:word_tokenize(x))

ndf['keywords'] = ndf['keywords'].map(lambda x:word_tokenize(x))

ndf['topics'] = ndf['topics'].map(lambda x:word_tokenize(str(x)))
ndf['groups'] = ndf['groups'].map(lambda x:word_tokenize(str(x)))

# %%
ndf.head()
# Out:
#                                                title  \
# 0         [Kernelized, Bayesian, Transfer, Learning]
# 1  [``, Source, Free, '', Transfer, Learning, for...
# 2  [A, Generalization, of, Probabilistic, Serial,...
# 3  [Lifetime, Lexical, Variation, in, Social, Media]
# 4  [Hybrid, Singular, Value, Thresholding, for, T...
#
#                                               groups  \
# 0  [Novel, Machine, Learning, Algorithms, (, NMLA...
# 1  [AI, and, the, Web, (, AIW, ), Novel, Machine,...
# 2  [Game, Theory, and, Economic, Paradigms, (, GT...
# 3              [NLP, and, Text, Mining, (, NLPTM, )]
# 4  [Knowledge, Representation, and, Reasoning, (,...
#
#                                             keywords  \
# 0  [cross-domain, learning, domain, adaptation, k...
# 1  [Transfer, Learning, Auxiliary, Data, Retrieva...
# 2  [social, choice, theory, voting, fair, divisio...
# 3  [Generative, model, Social, Networks, Age, Pre...
# 4  [tensor, completion, low-rank, recovery, hybri...
#
#                                               topics
# 0  [APP, :, Biomedical, Bioinformatics, NMLA, :, ...
# 1  [AIW, :, Knowledge, acquisition, from, the, we...
# 2  [GTEP, :, Game, Theory, GTEP, :, Social, Choic...
# 3  [AIW, :, Web, personalization, and, user, mode...
# 4  [KRR, :, Knowledge, Representation, (, General...

# %% [markdown]
# ### Stopwords_Removal

# %%
stop_words = set(stopwords.words('english'))

# %%
#removing stopwords from all the columns 
sw = set(stopwords.words('english'))
ndf['title'] = ndf['title'].map(lambda x:[w for w in x if w not in sw])
ndf['groups'] = ndf['groups'].map(lambda x:[w for w in x if w not in sw])
ndf['keywords'] = ndf['keywords'].map(lambda x:[w for w in x if w not in sw])
ndf['topics'] = ndf['topics'].map(lambda x:[w for w in x if w not in sw])

# %%
ndf.head()
# Out:
#                                                title  \
# 0         [Kernelized, Bayesian, Transfer, Learning]
# 1  [``, Source, Free, '', Transfer, Learning, Tex...
# 2  [A, Generalization, Probabilistic, Serial, Ran...
# 3      [Lifetime, Lexical, Variation, Social, Media]
# 4  [Hybrid, Singular, Value, Thresholding, Tensor...
#
#                                               groups  \
# 0  [Novel, Machine, Learning, Algorithms, (, NMLA...
# 1  [AI, Web, (, AIW, ), Novel, Machine, Learning,...
# 2    [Game, Theory, Economic, Paradigms, (, GTEP, )]
# 3                   [NLP, Text, Mining, (, NLPTM, )]
# 4  [Knowledge, Representation, Reasoning, (, KRR,...
#
#                                             keywords  \
# 0  [cross-domain, learning, domain, adaptation, k...
# 1  [Transfer, Learning, Auxiliary, Data, Retrieva...
# 2  [social, choice, theory, voting, fair, divisio...
# 3  [Generative, model, Social, Networks, Age, Pre...
# 4  [tensor, completion, low-rank, recovery, hybri...
#
#                                               topics
# 0  [APP, :, Biomedical, Bioinformatics, NMLA, :, ...
# 1  [AIW, :, Knowledge, acquisition, web, AIW, :, ...
# 2  [GTEP, :, Game, Theory, GTEP, :, Social, Choic...
# 3  [AIW, :, Web, personalization, user, modeling,...
# 4  [KRR, :, Knowledge, Representation, (, General...

# %% [markdown]
# ### Lemmatization

# %%
# Applying lemmatization in order to cut prefix and suffix and comparing with dictionary to get exact root words 
from nltk.stem import WordNetLemmatizer
lem = WordNetLemmatizer()
ndf['title'] = ndf['title'].map(lambda x:[lem.lemmatize(word) for word in x])
ndf['groups'] = ndf['groups'].map(lambda x:[lem.lemmatize(word) for word in x])
ndf['keywords'] = ndf['keywords'].map(lambda x:[lem.lemmatize(word) for word in x])
ndf['topics'] = ndf['topics'].map(lambda x:[lem.lemmatize(word) for word in x])

# %%
ndf.head()
# Out:
#                                                title  \
# 0         [Kernelized, Bayesian, Transfer, Learning]
# 1  [``, Source, Free, '', Transfer, Learning, Tex...
# 2  [A, Generalization, Probabilistic, Serial, Ran...
# 3      [Lifetime, Lexical, Variation, Social, Media]
# 4  [Hybrid, Singular, Value, Thresholding, Tensor...
#
#                                               groups  \
# 0  [Novel, Machine, Learning, Algorithms, (, NMLA...
# 1  [AI, Web, (, AIW, ), Novel, Machine, Learning,...
# 2    [Game, Theory, Economic, Paradigms, (, GTEP, )]
# 3                   [NLP, Text, Mining, (, NLPTM, )]
# 4  [Knowledge, Representation, Reasoning, (, KRR,...
#
#                                             keywords  \
# 0  [cross-domain, learning, domain, adaptation, k...
# 1  [Transfer, Learning, Auxiliary, Data, Retrieva...
# 2  [social, choice, theory, voting, fair, divisio...
# 3  [Generative, model, Social, Networks, Age, Pre...
# 4  [tensor, completion, low-rank, recovery, hybri...
#
#                                               topics
# 0  [APP, :, Biomedical, Bioinformatics, NMLA, :, ...
# 1  [AIW, :, Knowledge, acquisition, web, AIW, :, ...
# 2  [GTEP, :, Game, Theory, GTEP, :, Social, Choic...
# 3  [AIW, :, Web, personalization, user, modeling,...
# 4  [KRR, :, Knowledge, Representation, (, General...

# %% [markdown]
# ### Tf-Idf vectorizor

# %%
#applying tf-idf vectorisor in order to convert text into number (making of number matrix)
tf_idf_vectorizor = TfidfVectorizer(stop_words = 'english',max_features = 20000)

# %%
tf_idf_vectorizor
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=20000,
#                 min_df=1, ngram_range=(1, 1), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words='english', strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)

# %%
tf_idf = tf_idf_vectorizor.fit_transform(ndf)

# %%
ndf['title']=ndf['title'].apply(lambda x :(str(x).lower()))
ndf['groups']=ndf['groups'].apply(lambda x :(str(x).lower()))
ndf['keywords']=ndf['keywords'].apply(lambda x :(str(x).lower()))
ndf['topics']=ndf['topics'].apply(lambda x :(str(x).lower()))

# %%
tfidf = TfidfVectorizer(min_df = 5,
    max_df = 0.7,
    max_features = 8000,
    stop_words = 'english'
)
tfidf.fit(ndf["title"]+ndf["groups"]+ndf["topics"]+ndf["keywords"])
text = tfidf.transform(ndf["title"]+ndf["groups"]+ndf["topics"]+ndf["keywords"])
text
# Out:
# <398x342 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6385 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # K-Means Clustering

# %% [markdown]
# ### Elbow method for optimal K- value

# %%
#Finding optimum K value 
Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(text)
    Sum_of_squared_distances.append(km.inertia_)

# %%
km.inertia_
# Out:
# 250.3918665159485

# %%
#plotting elbow graph to get optimum K value for clusters
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# #### Hence we selected 9 clusters from elbow method

# %%
#Applying K-means clustering
clusters = KMeans(n_clusters=9, max_iter=100).fit_predict(text)
#AgglomerativeClustering(n_cluster=k_cluster,linkage="ward")
#SpectralClustering(n_cluster=k_clusters,affinity="precomputed,n_init=200")
#AffinityPropagation(damping=0.6)

# %% [markdown]
# # PCA & tSNE

# %%
#function to apply principle component analysis 
def plot_tsne_pca(data, labels):
    max_label = max(labels)
    max_items = np.random.choice(range(data.shape[0]), size=400, replace=True)
    
    pca = PCA(n_components=2).fit_transform(data[max_items,:].todense())
    tsne = TSNE().fit_transform(PCA(n_components=50).fit_transform(data[max_items,:].todense()))
    
    
    idx = np.random.choice(range(pca.shape[0]), size=300, replace=False)
    label_subset = labels[max_items]
    label_subset = [cm.hsv(i/max_label) for i in label_subset[idx]]
    
    f, ax = plt.subplots(1, 2, figsize=(14, 6))
    
    ax[0].scatter(pca[idx, 0], pca[idx, 1], c=label_subset)
    ax[0].set_title('PCA Cluster Plot')
    
    ax[1].scatter(tsne[idx, 0], tsne[idx, 1], c=label_subset)
    ax[1].set_title('TSNE Cluster Plot')
    
plot_tsne_pca(text, clusters)

# %%
#silhouette_score (-1: worst ) (1: best) (0: clusters are overlapping)
import sklearn
from sklearn.metrics import silhouette_score
sklearn.metrics.silhouette_score(text, clusters, metric='euclidean', sample_size=None, random_state=None)
# Out:
# 0.1079786813115805

# %% [markdown]
# #### Final clusters & keywords which are most important and relevant

# %%
def get_top_keywords(data, clusters, labels, n_terms):
    df = pd.DataFrame(data.todense()).groupby(clusters).mean()
    
    for i,r in df.iterrows():
        print('\nCluster {}'.format(i))
        print(','.join([labels[t] for t in np.argsort(r)[-n_terms:]]))
            
get_top_keywords(text, clusters, tfidf.get_feature_names(), 20)
# Out:
# Cluster 0
# cognitive,language,interaction,computer,nmla,rob,human,humans,supervised,cm,image,recognition,vision,hai,app,machine,vis,mla,applications,learning
#
# Cluster 1
# information,imperfect,coordination,computational,auctions,design,market,mechanism,equilibrium,multiagent,voting,systems,paradigms,economic,social,choice,mas,theory,game,gtep
#
# Cluster 2
# local,fast,machine,parallel,stochastic,nmla,general,deterministic,constraint,scs,learning,analysis,evaluation,ps,planning,scheduling,optimization,heuristic,hso,search
#
# Cluster 3
# spatial,languages,based,general,programming,ru,action,qualitative,diagnosis,ontologies,change,causality,logics,complexity,logic,description,representation,knowledge,reasoning,krr
#
# Cluster 4
# recommender,natural,networks,nlpkr,processing,nlpml,extraction,information,mining,machine,language,recommendation,nlp,learning,nlptm,text,ai,social,aiw,web
#
# Cluster 5
# dimension,ru,data,clustering,adaptation,multi,applications,bayesian,mla,reduction,selection,transfer,supervised,feature,classification,algorithms,novel,machine,nmla,learning
#
# Cluster 6
# programming,resolution,hso,mas,algorithm,tools,general,solvers,distributed,optimization,counting,global,constraints,csp,satisfiability,sat,search,satisfaction,constraint,scs
#
# Cluster 7
# optimization,making,temporal,relational,robotics,deterministic,krr,cs,rob,models,inference,decision,general,reasoning,probabilistic,uncertainty,scheduling,ru,ps,planning
#
# Cluster 8
# network,complex,dimensional,data,mining,management,applications,learning,mla,ai,prediction,phenomenon,control,optimization,computational,modeling,dynamic,sustainability,spatiotemporal,csai

# %% [markdown]
# # Keywords for SEO

# %% [raw]
# Game Theory
# Social Media Analytics
# Natural Language Processing(NLP)
# Optimization
# Computer Vision
# Robotics
# Model Learning
# Neural Networks
# Information Security
# Linear Programming
# Knowledge Graph
# Reasoning Based Models
# Probability Theory
# Recommender System
# Bayesian spam filtering
# Hidden Markov Model
# Decision Making
# Reinforcement Learning
# Data Mining
# Voice Recognition
# Web Analytics
# Planning & Scheduling
# Machine Learning Algorithm
# Human Diagnosis
# Heuristic Search
# Knowledge Representation & Reasoning
# Ontology
